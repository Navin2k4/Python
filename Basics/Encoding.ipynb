# %% [markdown]
# One hot Encodeing

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('airports.csv')
df.head()
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total Rf Heliport     40.070801
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.947733
# 3    6525  00AL  small_airport          Epps Airpark     34.864799
# 4  506791  00AN  small_airport  Katmai Lodge Airport     59.093287
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933601          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
# 3     -86.770302         820.0       NaN          US      US-AL       Harvest
# 4    -156.456699          80.0       NaN          US      US-AK   King Salmon
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 0                no      00A       NaN        00A       NaN            NaN
# 1                no     00AA       NaN       00AA       NaN            NaN
# 2                no     00AK       NaN       00AK       NaN            NaN
# 3                no     00AL       NaN       00AL       NaN            NaN
# 4                no     00AN       NaN       00AN       NaN            NaN
#
#   keywords
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df['type'].value_counts()
# Out:
# type
# small_airport     39679
# heliport          19362
# closed            10535
# medium_airport     4752
# seaplane_base      1155
# large_airport       465
# balloonport          49
# Name: count, dtype: int64

# %%
pd.get_dummies(df,columns=['type'])
# Out:
#            id    ident                       name  latitude_deg  \
# 0        6523      00A          Total Rf Heliport     40.070801
# 1      323361     00AA       Aero B Ranch Airport     38.704022
# 2        6524     00AK               Lowell Field     59.947733
# 3        6525     00AL               Epps Airpark     34.864799
# 4      506791     00AN       Katmai Lodge Airport     59.093287
# ...       ...      ...                        ...           ...
# 75992   46378  ZZ-0001            Sealand Helipad     51.894444
# 75993  307326  ZZ-0002  Glorioso Islands Airstrip    -11.584278
# 75994  346788  ZZ-0003      Fainting Goat Airport     32.110587
# 75995  342102     ZZZW     Scandium City Heliport     69.355287
# 75996  313629     ZZZZ     Satsuma Iōjima Airport     30.784722
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 0         -74.933601          11.0       NaN          US      US-PA
# 1        -101.473911        3435.0       NaN          US      US-KS
# 2        -151.692524         450.0       NaN          US      US-AK
# 3         -86.770302         820.0       NaN          US      US-AL
# 4        -156.456699          80.0       NaN          US      US-AK
# ...              ...           ...       ...         ...        ...
# 75992       1.482500          40.0        EU          GB     GB-ENG
# 75993      47.296389          11.0        AF          TF     TF-U-A
# 75994     -97.356312         690.0       NaN          US      US-TX
# 75995    -138.939310           4.0       NaN          CA      CA-YT
# 75996     130.270556         338.0        AS          JP      JP-46
#
#               municipality  ...                   home_link  \
# 0                 Bensalem  ...                         NaN
# 1                    Leoti  ...                         NaN
# 2             Anchor Point  ...                         NaN
# 3                  Harvest  ...                         NaN
# 4              King Salmon  ...                         NaN
# ...                    ...  ...                         ...
# 75992              Sealand  ...  http://www.sealandgov.org/
# 75993     Grande Glorieuse  ...                         NaN
# 75994                 Blum  ...                         NaN
# 75995  (Old) Scandium City  ...                         NaN
# 75996              Mishima  ...                         NaN
#
#                                           wikipedia_link  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 75992  https://en.wikipedia.org/wiki/Principality_of_...
# 75993                                                NaN
# 75994                                                NaN
# 75995                                                NaN
# 75996  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                     keywords type_balloonport type_closed type_heliport  \
# 0                        NaN            False       False          True
# 1                        NaN            False       False         False
# 2                        NaN            False       False         False
# 3                        NaN            False       False         False
# 4                        NaN            False       False         False
# ...                      ...              ...         ...           ...
# 75992   Roughs Tower Helipad            False       False          True
# 75993                    NaN            False       False         False
# 75994                    NaN            False       False         False
# 75995  ZZZW, ZZZW, ZYW, YK96            False        True         False
# 75996   SATSUMA,IWOJIMA,RJX7            False       False         False
#
#       type_large_airport  type_medium_airport  type_seaplane_base  \
# 0                  False                False               False
# 1                  False                False               False
# 2                  False                False               False
# 3                  False                False               False
# 4                  False                False               False
# ...                  ...                  ...                 ...
# 75992              False                False               False
# 75993              False                False               False
# 75994              False                False               False
# 75995              False                False               False
# 75996              False                False               False
#
#        type_small_airport
# 0                   False
# 1                    True
# 2                    True
# 3                    True
# 4                    True
# ...                   ...
# 75992               False
# 75993                True
# 75994                True
# 75995               False
# 75996                True
#
# [75997 rows x 24 columns]

# %% [markdown]
# Lable Encoding

# %%
import pandas as pd
import numpy as np


df1 = pd.read_csv('iris.csv')
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
import pandas as pd
import numpy as np


df1 = pd.read_csv('iris.csv')
df1['species'] = le.fit_transform(df1['species'])
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
df1.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
