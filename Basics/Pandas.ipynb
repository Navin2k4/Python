# %% [markdown]
# Pandas

# %%
import pandas as pd

# %% [markdown]
# Basics

# %%
# df = pd.read_csv('path') #Store the entire database

# %% [markdown]
# Pandas

# %% [markdown]
# It is like a column in a table
# One dimensional array holding data of any type

# %%
import pandas as pd

# %%
l1 = [3,6,8,10,30,22]

# %%
s1 = pd.Series(l1)

# %%
s1
# Out:
# 0     3
# 1     6
# 2     8
# 3    10
# 4    30
# 5    22
# dtype: int64

# %%
d1 = {"One":10,"Second":100,"Third":1000}

# %%
s2 = pd.Series(d1)

# %%
s2
# Out:
# One         10
# Second     100
# Third     1000
# dtype: int64

# %% [markdown]
# Pandas Dataframes

# %% [markdown]
# A pandas dataframe is a 2 dimensional data structure like a 2 dimensional array or a table with rows and columns

# %%
import pandas as pd

# %%
sample_data = {
    "Weekdays":["Sunday","Monday","Tuesday"],
    "TestScore":[10,20,30]
}

# %%
df = pd.DataFrame(sample_data)

# %%
df
# Out:
#   Weekdays  TestScore
# 0   Sunday         10
# 1   Monday         20
# 2  Tuesday         30

# %% [markdown]
# To access any particular row of the dataframe using the loc() function

# %%
df.loc[0]
# Out:
# Weekdays     Sunday
# TestScore        10
# Name: 0, dtype: object

# %% [markdown]
# Reading a CSV file

# %%
import pandas as pd

# %%
df = pd.read_csv('airports.csv')

# %%
df
# Out:
#            id    ident           type                       name  \
# 0        6523      00A       heliport          Total Rf Heliport
# 1      323361     00AA  small_airport       Aero B Ranch Airport
# 2        6524     00AK  small_airport               Lowell Field
# 3        6525     00AL  small_airport               Epps Airpark
# 4      506791     00AN  small_airport       Katmai Lodge Airport
# ...       ...      ...            ...                        ...
# 75992   46378  ZZ-0001       heliport            Sealand Helipad
# 75993  307326  ZZ-0002  small_airport  Glorioso Islands Airstrip
# 75994  346788  ZZ-0003  small_airport      Fainting Goat Airport
# 75995  342102     ZZZW         closed     Scandium City Heliport
# 75996  313629     ZZZZ  small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070801     -74.933601          11.0       NaN          US
# ...

# %% [markdown]
# Analyzing Data Frame in Pandas

# %% [markdown]
# Viewing the data using

# %% [markdown]
# head() method - top rows

# %%
df.head()
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total Rf Heliport     40.070801
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.947733
# 3    6525  00AL  small_airport          Epps Airpark     34.864799
# 4  506791  00AN  small_airport  Katmai Lodge Airport     59.093287
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933601          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
# 3     -86.770302         820.0       NaN          US      US-AL       Harvest
# 4    -156.456699          80.0       NaN          US      US-AK   King Salmon
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# ...

# %% [markdown]
# tail() method - last rows

# %%
df.tail()
# Out:
#            id    ident           type                       name  \
# 75992   46378  ZZ-0001       heliport            Sealand Helipad
# 75993  307326  ZZ-0002  small_airport  Glorioso Islands Airstrip
# 75994  346788  ZZ-0003  small_airport      Fainting Goat Airport
# 75995  342102     ZZZW         closed     Scandium City Heliport
# 75996  313629     ZZZZ  small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 75992     51.894444       1.482500          40.0        EU          GB
# 75993    -11.584278      47.296389          11.0        AF          TF
# 75994     32.110587     -97.356312         690.0       NaN          US
# 75995     69.355287    -138.939310           4.0       NaN          CA
# 75996     30.784722     130.270556         338.0        AS          JP
#
#       iso_region         municipality scheduled_service gps_code iata_code  \
# ...

# %% [markdown]
# Info about the data set

# %% [markdown]
# using info() method

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75997 entries, 0 to 75996
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 75997 non-null  int64
#  1   ident              75997 non-null  object
#  2   type               75997 non-null  object
#  3   name               75997 non-null  object
#  4   latitude_deg       75997 non-null  float64
#  5   longitude_deg      75997 non-null  float64
#  6   elevation_ft       61615 non-null  float64
#  7   continent          39295 non-null  object
#  8   iso_country        75738 non-null  object
#  9   iso_region         75997 non-null  object
#  10  municipality       70948 non-null  object
#  11  scheduled_service  75997 non-null  object
#  12  gps_code           41320 non-null  object
#  13  iata_code          8883 non-null   object
#  14  local_code         32740 non-null  object
#  15  home_link          3661 non-null   object
# ...

# %% [markdown]
# using describe() method

# %%
df.describe()
# Out:
#                   id  latitude_deg  longitude_deg  elevation_ft
# count   75997.000000  75997.000000   75997.000000  61615.000000
# mean   161131.756359     25.659801     -28.674753   1302.999140
# std    164250.080684     26.262577      86.234065   1672.892825
# min         2.000000    -90.000000    -179.876999  -1266.000000
# 25%     19147.000000     11.679400     -94.047990    206.000000
# 50%     40717.000000     35.121830     -69.383331    730.000000
# 75%    335185.000000     42.678699      24.198299   1617.000000
# max    510843.000000     82.750000     179.975700  17372.000000

# %% [markdown]
# using corr() method - correlation
